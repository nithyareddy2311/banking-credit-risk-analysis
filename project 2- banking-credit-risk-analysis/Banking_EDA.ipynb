# %%
# !pip install mysql-connector-python

# %%
import mysql.connector
import pandas as pd

# %%
import mysql.connector

cnx = mysql.connector.connect(
    host="127.0.0.1",
    port=3306,
    user="root",
    password="123456789",
    
)

print("Connected successfully!")
# Out:
# Connected successfully!

# %%
import mysql.connector
import pandas as pd

cnx = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="123456789",
    database="banking_case"
)

query = "SELECT * FROM customer"
df = pd.read_sql(query, cnx)

df
# Out:
# C:\Users\nithy\AppData\Local\Temp\ipykernel_10912\255046131.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, cnx)
#      ï»¿Client ID              Name  Age  Location ID Joined Bank  \
# 0        IND81288     Raymond Mills   24        34324  06-05-2019
# 1        IND65833     Julia Spencer   23        42205  10-12-2001
# 2        IND47499    Stephen Murray   27         7314  25-01-2010
# 3        IND72498    Virginia Garza   40        34594  28-03-2019
# 4        IND60181   Melissa Sanders   46        41269  20-07-2012
# ...           ...               ...  ...          ...         ...
# 2995     IND66827         Earl Hall   82         8760  09-10-2014
# 2996     IND40556  Billy Williamson   44        32837  05-02-2009
# 2997     IND72414      Victor Black   70        36088  29-12-2009
# ...

# %%
cnx.close()

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\project\Banking\Banking.csv")
df.head(5)
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df.rename(columns={'ï»¿Client ID': 'Client ID'}, inplace=True)

# %%
print(df.columns)
# Out:
# Index(['Client ID', 'Name', 'Age', 'Location ID', 'Joined Bank',
#        'Banking Contact', 'Nationality', 'Occupation', 'Fee Structure',
#        'Loyalty Classification', 'Estimated Income', 'Superannuation Savings',
#        'Amount of Credit Cards', 'Credit Card Balance', 'Bank Loans',
#        'Bank Deposits', 'Checking Accounts', 'Saving Accounts',
#        'Foreign Currency Account', 'Business Lending', 'Properties Owned',
#        'Risk Weighting', 'BRId', 'GenderId', 'IAId'],
#       dtype='object')

# %%
df.head(5)
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df.describe()
# Out:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
df.shape
# Out:
# (3000, 25)

# %%
df.isna().sum()
# Out:
# Client ID                   0
# Name                        0
# Age                         0
# Location ID                 0
# Joined Bank                 0
# Banking Contact             0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Credit Card Balance         0
# Bank Loans                  0
# Bank Deposits               0
# Checking Accounts           0
# Saving Accounts             0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# IAId                        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Joined Bank'].head()
# Out:
# 0    06-05-2019
# 1    10-12-2001
# 2    25-01-2010
# 3    28-03-2019
# 4    20-07-2012
# Name: Joined Bank, dtype: object

# %%
df['Joined Bank'] = pd.to_datetime(df['Joined Bank'], errors='coerce')

# %%
df[['Joined Bank']].dtypes
# Out:
# Joined Bank    datetime64[ns]
# dtype: object

# %%
bins = [0, 100000, 300000, float('inf')]
labels = ['Low', 'Med', 'High']

df['Income Band'] = pd.cut(df['Estimated Income'], bins=bins, labels=labels, right=False)

# %%
df['Income Band'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Income Band'>

# %%
Univariate Analysis

# %%
Numerical Analysis

# %%
numerical_cols = ['Estimated Income', 'Superannuation Savings', 'Credit Card Balance', 'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts', 'Foreign Currency Account', 'Business Lending']

# Univariate analysis and visualization
plt.figure(figsize=(15,10))
for i,col in enumerate(numerical_cols):
  plt.subplot(4,3,i+1)
  sns.histplot(df[col],kde=True)
  plt.title(col)
plt.tight_layout()
plt.show()

# %%
Heatmaps

# %%
numerical_cols = ['Estimated Income', 'Superannuation Savings', 'Credit Card Balance', 'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts', 'Foreign Currency Account', 'Business Lending']

correlation_matrix = df[numerical_cols].corr()

plt.figure(figsize=(6,6))
sns.heatmap(correlation_matrix, annot=True, cmap='crest', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Insights of EDA:
# The strongest positive correlation occur among "Bank Deposits" with "Checking Accounts", "Saving Accounts" and "Foreign Currency Account"
# indicating that customers who maintain high balances in one account type often hold substantial amount/funds across other accounts as well.

# %%
df["Estimated Income"]
# Out:
# 0        75384.77
# 1       289834.31
# 2       169935.23
# 3       356808.11
# 4       130711.68
#           ...
# 2995    297617.14
# 2996     42397.46
# 2997     48339.88
# 2998    107265.87
# 2999     56826.53
# Name: Estimated Income, Length: 3000, dtype: float64

# %%
# Define income band boundaries
bins = [0, 100000, 300000, float('inf')]
labels = ['Low', 'Mid', 'High']

# Create the 'Income Band' column using pd.cut
df['Income Band'] = pd.cut(df['Estimated Income'], bins=bins, labels=labels, include_lowest=True)

# %%
# Generate descriptive statistics for numerical columns
print("\nDescriptive Statistics for Numerical Columns:")
display(df.describe())
# Out:
# Descriptive Statistics for Numerical Columns:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# ...

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("Missing values per column:\n", missing_values)
# Out:
# Missing values per column:
#  Client ID                   0
# Name                        0
# Age                         0
# Location ID                 0
# Joined Bank                 0
# Banking Contact             0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Credit Card Balance         0
# Bank Loans                  0
# Bank Deposits               0
# Checking Accounts           0
# Saving Accounts             0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# IAId                        0
# Income Band                 0
# dtype: int64

# %%
df['Joined Bank'] = pd.to_datetime(df['Joined Bank'], format='%d-%m-%Y')
print(df['Joined Bank'].dtype)
# Out:
# datetime64[ns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Numerical analysis and exploration
numerical_cols = ['Fee Structure','Age', 'Estimated Income', 'Superannuation Savings', 'Credit Card Balance', 'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts', 'Foreign Currency Account', 'Business Lending']

# Univariate analysis and visualization
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(4, 3, i + 1)
    sns.histplot(df[col], kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# Select numerical columns for correlation analysis
numerical_cols = ['Age', 'Estimated Income', 'Superannuation Savings', 'Credit Card Balance',
                  'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts',
                  'Foreign Currency Account', 'Business Lending', 'Properties Owned']

# Calculate the correlation matrix
correlation_matrix = df[numerical_cols].corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(6, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
pairs_to_plot = [
    ('Bank Deposits', 'Saving Accounts'),
    ('Checking Accounts', 'Saving Accounts'),
    ('Checking Accounts', 'Foreign Currency Account'),
    ('Age', 'Superannuation Savings'),
    ('Estimated Income', 'Checking Accounts'),
    ('Bank Loans', 'Credit Card Balance'),
    ('Business Lending', 'Bank Loans'),
]

plt.figure(figsize=(16, 12))

for i, (x_col, y_col) in enumerate(pairs_to_plot):
    plt.subplot(3, 3, i + 1)

    sns.regplot(
        data=df,
        x=x_col,
        y=y_col,
        scatter_kws={'alpha': 0.4},
        line_kws={'color': 'red'}
    )

    plt.title(f'{x_col} vs {y_col}', fontsize=10)
    plt.xlabel(x_col, fontsize=9)
    plt.ylabel(y_col, fontsize=9)

plt.tight_layout()
plt.show()

# %%
Insights:
Deposits and Savings Behavior
The high correlation between Bank Deposits and Saving Accounts suggests that these may either measure overlapping financial behavior
(e.g., total funds a customer keeps in the bank) or that people who actively deposit funds also tend to maintain or grow savings balances.

Income, Age, and Accumulation
Moderate correlations of Age and Estimated Income with various balances (Superannuation, Savings, Checking)reflect a common financial lifecycle trend:
higher income earners and older individuals often accumulate more savings, retirement funds,and may carry higher credit card balances or loans.

Low Correlation with Properties Owned
Property ownership may depend on external factors (location, real estate market conditions, inheritance, etc.) 
that are not captured by these particular banking variables. Hence, we see weaker correlations here.

Business vs. Personal Banking
Business Lending’s moderate link to Bank Loans suggests some customers may have both personal and business debts.
However, business lending is relatively uncorrelated with other deposit or property-related metrics, indicating it may serve a distinct subset of 
customers or needs.

# %%
df[['Estimated Income', 'Bank Loans']].corr()
# Out:
#                   Estimated Income  Bank Loans
# Estimated Income          1.000000    0.329926
# Bank Loans                0.329926    1.000000

# %%
df.groupby('Risk Weighting')[['Bank Loans', 'Credit Card Balance']].mean()
# Out:
#                    Bank Loans  Credit Card Balance
# Risk Weighting
# 1               334192.148553          1882.421459
# 2               575784.755401          3081.658723
# 3               786634.906804          4110.491435
# 4               848689.886770          4504.116584
# 5               975216.615625          5299.862063

# %%
df.groupby('Loyalty Classification')['Estimated Income'].mean()
# Out:
# Loyalty Classification
# Gold        167876.148718
# Jade        172418.944673
# Platinum    163760.178202
# Silver      175105.559244
# Name: Estimated Income, dtype: float64

# %%
df.groupby('Joined Bank').size()
# Out:
# Joined Bank
# 01-01-1999    1
# 01-01-2007    1
# 01-01-2012    1
# 01-01-2013    1
# 01-01-2017    1
#              ..
# 31-12-2014    1
# 31-12-2015    1
# 31-12-2016    2
# 31-12-2020    1
# 31-12-2021    1
# Length: 2579, dtype: int64

# %%
df.groupby('Properties Owned')['Bank Deposits'].mean()
# Out:
# Properties Owned
# 0    686327.653518
# 1    656519.965915
# 2    698634.218468
# 3    644907.418787
# Name: Bank Deposits, dtype: float64

# %%
high_value = df[(df['Estimated Income'] > 800000) & (df['Bank Deposits'] > 500000)]
high_risk = df[(df['Risk Weighting'] >= 80) & (df['Bank Loans'] > df['Bank Deposits'])]

# %%
high_value, high_risk
# Out:
# (Empty DataFrame
#  Columns: [Client ID, Name, Age, Location ID, Joined Bank, Banking Contact, Nationality, Occupation, Fee Structure, Loyalty Classification, Estimated Income, Superannuation Savings, Amount of Credit Cards, Credit Card Balance, Bank Loans, Bank Deposits, Checking Accounts, Saving Accounts, Foreign Currency Account, Business Lending, Properties Owned, Risk Weighting, BRId, GenderId, IAId]
#  Index: []
#
#  [0 rows x 25 columns],
#  Empty DataFrame
#  Columns: [Client ID, Name, Age, Location ID, Joined Bank, Banking Contact, Nationality, Occupation, Fee Structure, Loyalty Classification, Estimated Income, Superannuation Savings, Amount of Credit Cards, Credit Card Balance, Bank Loans, Bank Deposits, Checking Accounts, Saving Accounts, Foreign Currency Account, Business Lending, Properties Owned, Risk Weighting, BRId, GenderId, IAId]
#  Index: []
#
#  [0 rows x 25 columns])

# %%
high_value = df[
    (df['Estimated Income'] > df['Estimated Income'].quantile(0.75)) &
    (df['Bank Deposits'] > df['Bank Deposits'].quantile(0.75))
]

high_value.head()
# Out:
#    Client ID            Name  Age  Location ID Joined Bank Banking Contact  \
# 3   IND72498  Virginia Garza   40        34594  28-03-2019      Steve Diaz
# 16  IND28503    Jack Coleman   61         9505  22-06-2014   Ernest Rivera
# 26  IND98618     Maria Clark   34         8623  29-01-2014      Joe Hanson
# 34  IND25680    Billy Wilson   73           99  25-09-2017   Dennis Morris
# 42  IND87800      Mark Mccoy   33        20816  24-01-2008  Patrick Graham
#
#    Nationality           Occupation Fee Structure Loyalty Classification  ...  \
# 3     American         Geologist II           Mid                 Silver  ...
# 16       Asian  Staff Accountant II          High                 Silver  ...
# 26       Asian   Help Desk Operator          High                 Silver  ...
# 34    European     Registered Nurse          High               Platinum  ...
# 42    European    Biostatistician I          High                 Silver  ...
#
# ...

# %%
high_risk = df[
    (df['Risk Weighting'] > df['Risk Weighting'].quantile(0.75)) &
    (df['Bank Loans'] > df['Bank Deposits'])
]

high_risk.head()
# Out:
#    Client ID            Name  Age  Location ID Joined Bank Banking Contact  \
# 19  IND32064        Mary Fox   63         7694  09-03-2009  Adam Hernandez
# 22  IND93121  Aaron Marshall   26        28661  14-01-2013   Ernest Rivera
# 53  IND54314     Kevin Gomez   32        24168  01-01-2007     Jerry Green
# 60  IND19011   Lillian Burns   47        33271  07-11-2003     Paul Larson
# 77  IND98220     Ruth Bishop   79         3957  24-01-2020       Joe Price
#
#    Nationality                    Occupation Fee Structure  \
# 19  Australian          Compensation Analyst           Mid
# 22    American              Media Manager IV           Mid
# 53    European               Project Manager           Mid
# 60    European               Sales Associate           Mid
# 77    American  Human Resources Assistant II          High
#
#    Loyalty Classification  ...  Bank Deposits  Checking Accounts  \
# 19                   Jade  ...      966281.34          472404.21
# ...

# %%
print("High Value Customers:", high_value.shape[0])
print("High Risk Customers:", high_risk.shape[0])
# Out:
# High Value Customers: 294
# High Risk Customers: 243

# %%
high_value = df[
    (df['Estimated Income'] > df['Estimated Income'].quantile(0.75)) &
    (df['Bank Deposits'] > df['Bank Deposits'].quantile(0.75))
]

high_risk = df[
    (df['Risk Weighting'] > df['Risk Weighting'].quantile(0.75)) &
    (df['Bank Loans'] > df['Bank Deposits'])
]
print("High Value Customers:", high_value.shape[0])
print("High Risk Customers:", high_risk.shape[0])
# Out:
# High Value Customers: 294
# High Risk Customers: 243

# %%
avg_income_loyalty = df.groupby('Loyalty Classification')['Estimated Income'].mean().reset_index()

plt.figure(figsize=(8,5))
plt.bar(avg_income_loyalty['Loyalty Classification'], avg_income_loyalty['Estimated Income'])
plt.title('Average Income by Loyalty Classification')
plt.xlabel('Loyalty Classification')
plt.ylabel('Average Income')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert Joined Bank to datetime
df["Joined Bank"] = pd.to_datetime(df["Joined Bank"], dayfirst=True)

# Extract year
df["Join Year"] = df["Joined Bank"].dt.year

# Count customers per year
yearly_customers = df.groupby("Join Year").size()

# Line chart
plt.figure()
plt.plot(yearly_customers.index, yearly_customers.values)
plt.title("Year-wise Trend of Customers Joining the Bank")
plt.xlabel("Year")
plt.ylabel("Number of Customers")
plt.show()

# %%
plt.figure()
df.boxplot(column="Risk Weighting", by="Properties Owned")
plt.title("Risk Weighting by Properties Owned")
plt.suptitle("")
plt.xlabel("Properties Owned")
plt.ylabel("Risk Weighting")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure()

box = df.boxplot(
    column="Risk Weighting",
    by="Properties Owned",
    patch_artist=True
)

# Set color for each box
colors = ["lightblue", "lightgreen", "lightyellow", "lightpink"]

for patch, color in zip(box.artists, colors):
    patch.set_facecolor(color)

plt.title("Risk Weighting by Properties Owned")
plt.suptitle("")
plt.xlabel("Properties Owned")
plt.ylabel("Risk Weighting")
plt.show()

# %%
plt.figure()
plt.scatter(df["Bank Deposits"], df["Bank Loans"])
plt.title("Bank Deposits vs Bank Loans")
plt.xlabel("Bank Deposits")
plt.ylabel("Bank Loans")
plt.show()
